# %% [markdown]
#  <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#dc143c;
#            font-size:200%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding:40px;text-align:center;
#               color:white;">
#             Supermarket Sales EDA Vısualization
#         </p>
#     </div>
#     </p>
# </div>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:black;">
#             The growth of supermarkets in most populated cities are increasing and market competitions are also high. The dataset is one of the historical sales of supermarket company which has recorded in 3 different branches for 3 months data. Predictive data analytics methods are easy to apply with this dataset.
#         </p>
#     </div>
#     </p>
# </div>

# %% [markdown]
# ![resim.jpg](attachment:ef8f91aa-37a6-42a6-95a1-e949c8940261.jpg)

# %% [markdown]
# ### <span style="color:red">Attribute information</span>
# 1. Invoice id: Computer generated sales slip invoice identification number
# 1. Branch: Branch of supercenter (3 branches are available identified by A, B and C).
# 1. City: Location of supercenters
# 1. Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
# 1. Gender: Gender type of customer
# 1. Product line: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
# 1. Unit price: Price of each product in $
# 1. Quantity: Number of products purchased by customer
# 1. Tax: 5% tax fee for customer buying
# 1. Total: Total price including tax
# 1. Date: Date of purchase (Record available from January 2019 to March 2019)
# 1. Time: Purchase time (10am to 9pm)
# 1. Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
# 1. COGS: Cost of goods sold
# 1. Gross margin percentage: Gross margin percentage
# 1. Gross income: Gross income
# 1. Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %% [markdown]
# ### <span style="color:red">CONTENT</span>
#
# 1. [Read Datas](#1)
#     * [Simple Analysis Of Data](#2)
# 1. [Checking Null Value](#3)
# 1. [DATA VISUALIZATION](#4)
#     * [BAR PLOT](#5)
#         * [OBJECT VARİABLE](#6)
#         * [NUMERİC VARİABLE](#7)
# 1. [Outlier Detection](#7)
# 1. [Missing Value](#8)
#     * [Find Missing Value](#9)
#     * [Fill Missing Value](#10)

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             READ DATAS
#         </p>
#     </div>
#     </p>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import warnings
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/supermarket-sales/supermarket_sales - Sheet1.csv

# %%
data = pd.read_csv("/kaggle/input/supermarket-sales/supermarket_sales - Sheet1.csv")

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data['City'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 1000, dtype: object>

# %%
data['City'].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
data['Branch'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
data['Customer type'].unique()
# Out:
# array(['Member', 'Normal'], dtype=object)

# %%
data['Product line'].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
data['Payment'].unique()
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
data.shape
# Out:
# (1000, 17)

# %%
data.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data.value_counts()
# Out:
# Invoice ID   Branch  City       Customer type  Gender  Product line         Unit price  Quantity  Tax 5%   Total     Date       Time   Payment      cogs    gross margin percentage  gross income  Rating
# 101-17-6199  A       Yangon     Normal         Male    Food and beverages   45.79       7         16.0265  336.5565  3/13/2019  19:44  Credit card  320.53  4.761905                 16.0265       7.0       1
# 641-62-7288  B       Mandalay   Normal         Male    Home and lifestyle   99.92       6         29.9760  629.4960  3/24/2019  13:33  Ewallet      599.52  4.761905                 29.9760       7.1       1
# 633-91-1052  A       Yangon     Normal         Female  Home and lifestyle   12.03       2         1.2030   25.2630   1/27/2019  15:51  Cash         24.06   4.761905                 1.2030        5.1       1
# ...

# %%
data.corr()
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
#
#                          gross margin percentage  gross income    Rating
# Unit price                                   NaN      0.633962 -0.008778
# Quantity                                     NaN      0.705510 -0.015815
# ...

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
data['Branch'].value_counts(dropna=True)
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             Simple Analysis Of Data
#         </p>
#     </div>
#     </p>
# </div>

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
x = data['Branch']=='C'
data[x]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 20   300-71-4605      C  Naypyitaw        Member    Male
# 34   183-56-6882      C  Naypyitaw        Member  Female
# ..           ...    ...        ...           ...     ...
# 983  148-41-7930      C  Naypyitaw        Normal    Male
# 984  189-40-5216      C  Naypyitaw        Normal    Male
# 988  267-62-7380      C  Naypyitaw        Member    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 5    Electronic accessories       85.39         7  29.8865  627.6165
# 7        Home and lifestyle       73.56        10  36.7800  772.3800
# ...

# %%
data[(data['Total']>1000) & (data['Payment']=='Credit card') & (data['Branch']=='C') ]
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
# 422  271-88-8734      C  Naypyitaw        Member  Female  Fashion accessories
#
#      Unit price  Quantity  Tax 5%     Total       Date   Time      Payment  \
# 350       99.30        10  49.650  1042.650  2/15/2019  14:53  Credit card
# 422       97.21        10  48.605  1020.705   2/8/2019  13:00  Credit card
#
#       cogs  gross margin percentage  gross income  Rating
# 350  993.0                 4.761905        49.650     6.6
# 422  972.1                 4.761905        48.605     8.7

# %%
data[ (data['Payment']=='Cash')  | (data['Branch']=='A')  ]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 990  886-18-2897      A     Yangon        Normal  Female
# 992  745-74-0715      A     Yangon        Normal    Male
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
data[ (data['Unit price']<20) & (data['cogs']<20) & (data['Branch']=='A')  ]
# Out:
#       Invoice ID Branch    City Customer type  Gender         Product line  \
# 69   382-03-4532      A  Yangon        Member  Female    Health and beauty
# 215  802-43-8934      A  Yangon        Normal    Male   Home and lifestyle
# 282  490-29-1201      A  Yangon        Normal  Female    Sports and travel
# 629  308-39-1707      A  Yangon        Normal  Female  Fashion accessories
# 732  756-49-0168      A  Yangon        Member    Male  Fashion accessories
# 962  593-08-5916      A  Yangon        Normal  Female  Fashion accessories
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 69        18.33         1  0.9165  19.2465   2/2/2019  18:50         Cash
# 215       18.28         1  0.9140  19.1940  3/22/2019  15:05  Credit card
# 282       15.34         1  0.7670  16.1070   1/6/2019  11:09         Cash
# 629       12.09         1  0.6045  12.6945  1/26/2019  18:19  Credit card
# ...

# %%
data['Payment'].unique()
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
data1=data['Gender'].head()
data2=data['City'].head()
data_concat=pd.concat([data1,data2],axis=1)
data_concat
# Out:
#    Gender       City
# 0  Female     Yangon
# 1  Female  Naypyitaw
# 2    Male     Yangon
# 3    Male     Yangon
# 4    Male     Yangon

# %%
data[["Gender","City"]]
# Out:
#      Gender       City
# 0    Female     Yangon
# 1    Female  Naypyitaw
# 2      Male     Yangon
# 3      Male     Yangon
# 4      Male     Yangon
# ..      ...        ...
# 995    Male  Naypyitaw
# 996  Female   Mandalay
# 997    Male     Yangon
# 998    Male     Yangon
# 999  Female     Yangon
#
# [1000 rows x 2 columns]

# %%
data.loc[1:20,"Unit price":"Payment"]
# Out:
#     Unit price  Quantity   Tax 5%     Total       Date   Time      Payment
# 1        15.28         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2        46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3        58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4        86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
# 5        85.39         7  29.8865  627.6165  3/25/2019  18:30      Ewallet
# 6        68.84         6  20.6520  433.6920  2/25/2019  14:36      Ewallet
# 7        73.56        10  36.7800  772.3800  2/24/2019  11:38      Ewallet
# 8        36.26         2   3.6260   76.1460  1/10/2019  17:15  Credit card
# 9        54.84         3   8.2260  172.7460  2/20/2019  13:27  Credit card
# 10       14.48         4   2.8960   60.8160   2/6/2019  18:07      Ewallet
# 11       25.51         4   5.1020  107.1420   3/9/2019  17:03         Cash
# ...

# %%
data.loc[15:20,"Unit price":]
# Out:
#     Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 15       93.72         6  28.1160  590.4360  1/15/2019  16:19         Cash
# 16       68.93         7  24.1255  506.6355  3/11/2019  11:03  Credit card
# 17       72.61         6  21.7830  457.4430   1/1/2019  10:39  Credit card
# 18       54.67         3   8.2005  172.2105  1/21/2019  18:00  Credit card
# 19       40.30         2   4.0300   84.6300  3/11/2019  15:30      Ewallet
# 20       86.04         5  21.5100  451.7100  2/25/2019  11:24      Ewallet
#
#       cogs  gross margin percentage  gross income  Rating
# 15  562.32                 4.761905       28.1160     4.5
# 16  482.51                 4.761905       24.1255     4.6
# 17  435.66                 4.761905       21.7830     6.9
# 18  164.01                 4.761905        8.2005     8.6
# 19   80.60                 4.761905        4.0300     4.4
# 20  430.20                 4.761905       21.5100     4.8

# %%
boolean=data.Quantity<2
data[boolean]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 26   649-29-6775      B   Mandalay        Normal    Male
# 35   232-16-2483      C  Naypyitaw        Member  Female
# 40   280-35-5823      B   Mandalay        Member  Female
# 53   778-71-5554      C  Naypyitaw        Member    Male
# 69   382-03-4532      A     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 979  151-33-7434      B   Mandalay        Normal  Female
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
#
#                Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 26      Fashion accessories       33.52         1  1.6760  35.1960   2/8/2019
# 35        Sports and travel       68.12         1  3.4060  71.5260   1/7/2019
# ...

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
first_filter=data.Gender=='Female'
second_filter=data.Quantity >9
data[first_filter & second_filter]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 14   829-34-3910      A     Yangon        Normal  Female
# 49   574-22-5561      C  Naypyitaw        Member  Female
# 58   817-48-8732      A     Yangon        Member  Female
# 75   732-94-0499      C  Naypyitaw        Normal  Female
# ..           ...    ...        ...           ...     ...
# 942  809-69-9497      A     Yangon        Normal  Female
# 958  867-47-1948      C  Naypyitaw        Normal  Female
# 970  746-04-1077      B   Mandalay        Member  Female
# 991  602-16-6955      B   Mandalay        Normal  Female
# 996  303-96-2227      B   Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity  Tax 5%     Total  \
# 7        Home and lifestyle       73.56        10  36.780   772.380
# 14        Health and beauty       71.38        10  35.690   749.490
# 49      Fashion accessories       82.63        10  41.315   867.615
# ...

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             Checking Null Value
#         </p>
#     </div>
#     </p>
# </div>

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data.columns[data.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
data[data["Customer type"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, City, Customer type, Gender, Product line, Unit price, Quantity, Tax 5%, Total, Date, Time, Payment, cogs, gross margin percentage, gross income, Rating]
# Index: []

# %% [markdown]
#  <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#dc143c;
#            font-size:200%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding:40px;text-align:center;
#               color:white;">
#             DATA VISUALIZATION
#         </p>
#     </div>
#     </p>
# </div>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             BAR PLOT
#         </p>
#     </div>
#     </p>
# </div>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             OBJECT VARİABLE
#         </p>
#     </div>
#     </p>
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
def bar_plot(variable):
  
    # get feature
    var =data[variable]
    # count number of categorical variable(value/sample)
    varValue = var.value_counts()
    
    # visualize
    plt.figure(figsize = (3,3))
    plt.bar(varValue.index, varValue,color='purple')
    plt.xticks(varValue.index, varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
category1 = ["Branch","City","Customer type","Gender","Payment", "Product line"]
for c in category1:
    bar_plot(c)
# Out:
# Branch:
#  A    340
# B    332
# C    328
# Name: Branch, dtype: int64
# City:
#  Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64
# Customer type:
#  Member    501
# Normal    499
# Name: Customer type, dtype: int64
# Gender:
#  Female    501
# Male      499
# Name: Gender, dtype: int64
# Payment:
#  Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64
# Product line:
#  Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             NUMERİC VARİABLE
#         </p>
#     </div>
#     </p>
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
def plot_hist(variable):
    plt.figure(figsize = (3,3))
    plt.hist(data[variable], bins = 50,color='red')
    plt.xlabel(variable)
    plt.ylabel("Frequency")
    plt.title("{} distribution with hist".format(variable))
    plt.show()

# %%
numericVar = ["Unit price", "Quantity","Tax 5%","Total", "cogs","gross margin percentage","Rating"]
for n in numericVar:
    plot_hist(n)

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             POİNT PLOT
#         </p>
#     </div>
#     </p>
# </div>

# %% [markdown]
# ![![image.png](attachment:f77fe29e-e755-4d06-8d0f-492d385d990f.png)

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data.rename(columns ={'Unit price':'Unit_price'},inplace=True)
data["miktar_fiyat"]=data.Unit_price* data.Quantity
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit_price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#Total: Vergi dahil toplam fiyat
#COGS: Satılan malın maliyeti
#total vs cogs
# visualize
f,ax1 = plt.subplots(figsize =(15,15))

sns.pointplot(x='Quantity',y='cogs',data=data,color='lime',alpha=0.8)
sns.pointplot(x='Quantity',y='Total',data=data,color='red',alpha=0.8)

plt.text(0.2,50,'Total price',color='red',fontsize = 17,style = 'italic')
plt.text(0.2,35,'Cost of goods sold',color='lime',fontsize = 18,style = 'italic')

plt.xlabel('cogs',fontsize = 15,color='blue')
plt.ylabel('total',fontsize = 15,color='blue')
plt.title('Total vs Cogs',fontsize = 20,color='blue')
plt.grid()

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             Joint Plot
#         </p>
#     </div>
#     </p>
# </div>

# %% [markdown]
# ![![image.png](attachment:d4e21e40-4399-4b22-a735-273986fa4e98.png)

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit_price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sns.color_palette("flare", as_cmap=True)

# %%
# Visualization 
# joint kernel density
# pearsonr= if it is 1, there is positive correlation and if it is, -1 there is negative correlation.
# If it is zero, there is no correlation between variables
# Show the joint distribution using kernel density estimation 

#sns.set_theme(style="darkgrid")
sns.color_palette("flare", as_cmap=True)
sns.jointplot(data.cogs, data.Unit_price, kind="kde", height=7,fill=True,palette='flare')

plt.savefig('graph.png')
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(data.miktar_fiyat, data.Quantity, kind="hex", height=7,color='m')
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             PİE CHART
#         </p>
#     </div>
#     </p>
# </div>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:100%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             In addition to the basic pie chart, this demo shows a few optional features:
#
# slice labels
#
# auto-labeling the percentage
#
# offsetting a slice with "explode"
#
# drop-shadow
#
# custom start angle
#
# Note about the custom start angle:
#         </p>
#     </div>
#     </p>
# </div>

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit_price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
# pie card by city
data.City.dropna(inplace = True)
labels = data.City.value_counts().index #sözel değerler
colors = ['pink','purple','red']
explode = [0,0,1] #
sizes = data.City.value_counts().values #sayısal değerler

# visual
plt.figure(figsize = (7,7))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('pie card by city',color = 'black',fontsize = 15)
# Out:
# Text(0.5, 1.0, 'pie card by city')

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:200%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             LM PLOT
#         </p>
#     </div>
#     </p>
# </div>

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit_price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
# Visualization of high school graduation rate vs Poverty rate of each state with different style of seaborn code
# lmplot 
# Show the results of a linear regression within each dataset
#Condition across two variables using both columns and rows:
sns.lmplot(x="Unit_price", y="cogs",col="Product line", row="Payment", data=data ,hue="Gender",height=7)
plt.show()

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:200%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             KDE PLOT
#         </p>
#     </div>
#     </p>
# </div>

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit_price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
f,ax = plt.subplots(figsize=(15,15))
sns.kdeplot(
   data=data, x="Total", hue="Quantity",
   fill=True, common_norm=False, palette="crest",gridsize=200, shade=True, cut=3,
   alpha=.5, linewidth=0,ax=ax
)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Density'>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:200%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             Violin Plot
#         </p>
#     </div>
#     </p>
# </div>

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit_price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
f,ax = plt.subplots(figsize=(15,15))
sns.violinplot(data=data, y="Unit_price", x="Branch", scale="count",hue="Payment",ax=ax)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Unit_price'>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:200%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             Heatmap
#         </p>
#     </div>
#     </p>
# </div>

# %%
data.corr()
# Out:
#                          Unit_price  Quantity    Tax 5%     Total      cogs  \
# Unit_price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
# miktar_fiyat               0.633962  0.705510  1.000000  1.000000  1.000000
#
#                          gross margin percentage  gross income    Rating  \
# Unit_price                                   NaN      0.633962 -0.008778
# ...

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit_price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#correlation map
#Visualization of 
f,ax = plt.subplots(figsize=(15,15))
sns.heatmap(data.corr(), annot=True, linewidths=0.5,linecolor="purple", fmt= '.1f',ax=ax)
plt.show()

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:200%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             Box Plot
#         </p>
#     </div>
#     </p>
# </div>

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit_price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data.rename(columns ={'Product line':'Product_line'},inplace=True)

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product_line  Unit_price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data.Product_line.unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
f,ax = plt.subplots(figsize=(15,15))
sns.boxplot(y="Quantity", x="Product_line", data=data, palette="flare",ax=ax)
plt.show()

# %%
 sns.boxplot(x="Branch", y = "Rating" ,data =data).set_title("Ratings by Branch")
# Out:
# Text(0.5, 1.0, 'Ratings by Branch')

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:200%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             Swarm Plot
#         </p>
#     </div>
#     </p>
# </div>

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product_line  Unit_price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
f,ax = plt.subplots(figsize=(15,15))
sns.swarmplot(x="Payment", y="Total",hue="Customer type", data=data,ax=ax)
plt.show()

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:#fff0f5;
#            font-size:200%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 30px;text-align:center;
#               color:#dc143c;">
#             Count Plot
#         </p>
#     </div>
#     </p>
# </div>

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product_line  Unit_price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
# gender properties

sns.countplot(data.Gender)
#sns.countplot(kill.manner_of_death)
plt.title("gender",color = 'blue',fontsize=15)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'gender')

# %%
data.Quantity
# Out:
# 0       7
# 1       5
# 2       7
# 3       8
# 4       7
#        ..
# 995     1
# 996    10
# 997     1
# 998     1
# 999     7
# Name: Quantity, Length: 1000, dtype: int64

# %%
# Most dangerous cities
quantity = data.Quantity.value_counts()
plt.figure(figsize=(10,7))
sns.barplot(x=quantity.index,y=quantity.values)
plt.xticks(rotation=45)
plt.title('quantity',color = 'blue',fontsize=15)
# Out:
# Text(0.5, 1.0, 'quantity')

# %% [markdown]
# Payment Channel

# %%
 sns.countplot(x="Payment", data =data).set_title("Payment Channel")
# Out:
# Text(0.5, 1.0, 'Payment Channel')

# %%
 sns.countplot(x="Payment", hue = "Branch", data =data).set_title("Payment Channel by Branch")
# Out:
# Text(0.5, 1.0, 'Payment Channel by Branch')

# %% [markdown]
# Customer Analysis

# %%
sns.countplot(x="Customer type", data =data).set_title("Customer Type")
# Out:
# Text(0.5, 1.0, 'Customer Type')

# %%
sns.countplot(x="Customer type", hue = "Branch", data =data).set_title("Customer Type by Branch")
# Out:
# Text(0.5, 1.0, 'Customer Type by Branch')

# %% [markdown]
# Does customer type influences the sales

# %%
data.groupby(['Customer type']).agg({'Total': 'sum'})
# Out:
#                     Total
# Customer type
# Member         164223.444
# Normal         158743.305

# %%
 sns.swarmplot(x="Customer type",  y = "Rating",  hue = "City", data =data).set_title("Customer Type")
# Out:
# Text(0.5, 1.0, 'Customer Type')
